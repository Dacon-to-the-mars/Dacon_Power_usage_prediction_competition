# %% [markdown]
# ## Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
import random
import os

def reset_seeds(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

DATA_PATH = "/content/drive/MyDrive/data/"

SEED = 42

# %%
reset_seeds(SEED)

# %%
pred67= pd.read_csv(f"{DATA_PATH}67번.csv")
pred73= pd.read_csv(f"{DATA_PATH}73번.csv")
pred81= pd.read_csv(f"{DATA_PATH}81번.csv")

# %%
pred67['answer']*0.35+pred73['answer']*0.3+pred81['answer']*0.35
# Out:
# 0        1912.629269
# 1        1843.150676
# 2        1677.025342
# 3        1628.485564
# 4        1616.596915
#             ...
# 16795     918.804543
# 16796     782.314272
# 16797     709.763554
# 16798     608.910768
# 16799     509.998508
# Name: answer, Length: 16800, dtype: float64

# %%
pred67['answer'] = pred67['answer']*0.35+pred73['answer']*0.3+pred81['answer']*0.35

# %%
pred67
# Out:
#          num_date_time       answer
# 0        1_20220825 00  1912.629269
# 1        1_20220825 01  1843.150676
# 2        1_20220825 02  1677.025342
# 3        1_20220825 03  1628.485564
# 4        1_20220825 04  1616.596915
# ...                ...          ...
# 16795  100_20220831 19   918.804543
# 16796  100_20220831 20   782.314272
# 16797  100_20220831 21   709.763554
# 16798  100_20220831 22   608.910768
# 16799  100_20220831 23   509.998508
#
# [16800 rows x 2 columns]

# %%
pred67.to_csv(f"{DATA_PATH}final_submission.csv",index=False)
